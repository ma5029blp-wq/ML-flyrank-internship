# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ma5029blp-wq/ML-flyrank-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# 1. My Lane (or Freestyle) and Why
#
# Lane: Refresh / Content Opportunity Scoring
#
# I chose the Refresh / Content Opportunity Scoring lane because it focuses on helping content teams decide which pages should be reviewed first. Websites often have hundreds or thousands of pages, making it difficult to review every page manually. By analyzing observable search and engagement signals, this project aims to rank pages based on their likelihood of needing a content refresh. The goal is to support human decision-making with evidence-based recommendations rather than replacing human judgment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Selected Lane:  Refresh / Content Opportunity Scoring")
# Out:
# Selected Lane:  Refresh / Content Opportunity Scoring

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision
#
# The project improves the decision of which pages should be reviewed first for content updates.
#
# Who Takes the Action?
#
# A content manager or SEO specialist reviews the ranked list and decides whether to refresh, expand, rewrite, monitor, or leave a page unchanged.
#
# Cost of a Wrong Recommendation
#
# A false positive means reviewers spend time on pages that do not need updating, reducing productivity. A false negative is more costly because an important declining page may be missed, allowing traffic and user engagement to continue decreasing. Therefore, the ranking should help reviewers focus on the pages most likely to benefit from attention while accepting that human review is still necessary.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# * Quick look at the data (2–3 real numbers)
#
# The starter dataset contains 30,000 content pages, providing a large enough sample for analyzing refresh opportunities.
#
# The average Click-Through Rate (CTR) is 0.51, showing that there is variation in how effectively pages convert impressions into clicks.
#
# The dataset also contains 16,262 pages with a "down" trend direction, which is more than half of all pages. This indicates there are many potential candidates for content review and prioritization, making the Refresh / Content Opportunity Scoring lane a meaningful problem to study over the next seven weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Use the same CSV path from Notebook 1
df = pd.read_csv("content_refresh_anonymized.csv")

print("Total Pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(),2))
print("\nTrend Direction Counts:")
print(df["trend_direction"].value_counts())
# Out:
# Total Pages: 30000
# Average CTR: 0.51
#
# Trend Direction Counts:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project provides decision-support, not automatic decision-making. It analyzes observable search and engagement signals to identify pages that may deserve review. The ranked recommendations indicate which pages appear to have the strongest evidence for a refresh opportunity.
#
# However, this project cannot prove that refreshing a page will increase traffic or improve search rankings. It also does not predict Google's algorithms or establish causal relationships. Any recommendations should be reviewed by a human before action is taken, and the results should be interpreted as evidence-based guidance rather than guaranteed outcomes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("This project povides decidin support not guaranteed predictions")
# Out:
# This project povides decidin support not guaranteed predictions

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
